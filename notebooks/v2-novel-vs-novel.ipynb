# %%
import re

def tokenize(text: str):
    return re.findall('[a-z]+', text.lower())

# %%
from difflib import SequenceMatcher

def print_matches(subject, query, min_size=5):
    
    s_tokens = tokenize(subject)
    q_tokens = tokenize(query)
    
    matcher = SequenceMatcher(a=s_tokens, b=q_tokens, autojunk=False)
    
    for m in matcher.get_matching_blocks():
        if m.size > min_size:
            print(s_tokens[m.a:m.a+m.size])

# %%
with open('data/pg284.txt') as fh:
    house_of_mirth = fh.read()
    
with open('data/pg2891.txt') as fh:
    howards_end = fh.read()

# %%
print_matches(house_of_mirth, howards_end, 0)
# Out:
# ['the', 'project', 'gutenberg']
# ['of']
# ['end', 'by']
# ['m']
# ['in', 'our']
# ['by']
# ['m']
# ['are']
# ['changing']
# ['all', 'over', 'the', 'world']
# ['at']
# ['the']
# ['in']
# ['to']
# ['it']
# ['to']
# ['with', 'the']
# ['about']
# ['they', 'can']
# ['with', 'the']
# ['to']
# ['the', 'world', 'of']
# ['and']
# ['of']
# ['in']
# ['as', 'the']
# ['to']
# ['be']
# ['in', 'the']
# ['these']
# ['should', 'be']
# ['made', 'to']
# ['we', 'are']
# ['of']
# ['the', 'project', 'gutenberg']
# ['of']
# ['by']
# ['this', 'file', 'should', 'be', 'named', 'txt', 'or', 'zip', 'this']
# ['and']
# ['files']
# ['of']
# ['will', 'be']
# ['in']
# ['http', 'www', 'gutenberg']
# ['org']
# ['will']
# ['the']
# ['the']
# ['public', 'domain']
# ['print']
# ['means', 'that', 'no', 'one', 'owns', 'a', 'united', 'states', 'copyright']
# ['so', 'the']
# ['and', 'you', 'can', 'copy', 'and', 'distribute', 'it', 'in', 'the', 'united', 'states', 'without', 'permission', 'and', 'without', 'paying', 'copyright', 'royalties', 'special', 'rules', 'set', 'forth']
# ['apply']
# ['if', 'you', 'wish', 'to']
# ['distribute']
# ['project', 'gutenberg']
# ['the', 'project', 'gutenberg']
# ['the', 'project']
# ['considerable']
# ['to', 'identify']
# ['transcribe', 'and', 'proofread', 'public', 'domain', 'works']
# ['despite', 'these', 'efforts']
# ['project']
# ['and']
# ['medium']
# ['they', 'may', 'be']
# ['may', 'contain', 'defects']
# ['incomplete', 'inaccurate', 'or', 'corrupt', 'data', 'transcription', 'errors', 'a', 'copyright', 'or', 'other', 'intellectual', 'property', 'infringement', 'a', 'defective', 'or', 'damaged', 'disk', 'or', 'other']
# ['medium', 'a', 'computer', 'virus', 'or', 'computer', 'codes', 'that', 'damage', 'or', 'cannot', 'be', 'read', 'by', 'your', 'equipment']
# ['limited', 'warranty', 'disclaimer', 'of', 'damages']
# ['for', 'the', 'right', 'of', 'replacement', 'or', 'refund', 'described']
# ['the', 'project']
# ['and', 'any', 'other', 'party']
# ['a', 'project', 'gutenberg', 'tm']
# ['all', 'liability', 'to', 'you', 'for', 'damages', 'costs', 'and', 'expenses', 'including', 'legal', 'fees']
# ['you', 'have', 'no', 'remedies', 'for', 'negligence']
# ['strict', 'liability']
# ['breach', 'of', 'warranty', 'or']
# ['contract']
# ['not']
# ['to']
# ['indirect', 'consequential', 'punitive', 'or', 'incidental', 'damages', 'even', 'if', 'you', 'give', 'notice', 'of', 'the', 'possibility', 'of', 'such']
# ['if', 'you', 'discover', 'a', 'defect', 'in', 'this']
# ['within', 'days', 'of', 'receiving', 'it', 'you', 'can', 'receive', 'a', 'refund', 'of', 'the', 'money', 'if', 'any', 'you', 'paid', 'for', 'it', 'by', 'sending']
# ['to', 'the', 'person', 'you', 'received']
# ['from', 'if', 'you', 'received']
# ['on', 'a', 'physical', 'medium', 'you', 'must', 'return']
# ['with', 'your']
# ['person']
# ['you']
# ['a', 'replacement', 'copy']
# ['if', 'you', 'received']
# ['electronically']
# ['person']
# ['may', 'choose', 'to']
# ['give', 'you', 'a', 'second', 'opportunity', 'to', 'receive']
# ['electronically']
# ['is']
# ['provided', 'to', 'you', 'as', 'is']
# ['no', 'other', 'warranties', 'of', 'any', 'kind', 'express', 'or', 'implied']
# ['including', 'but', 'not', 'limited', 'to', 'warranties', 'of']
# ['or', 'fitness', 'for']
# ['purpose']
# ['some', 'states', 'do', 'not', 'allow', 'disclaimers', 'of']
# ['implied', 'warranties', 'or', 'the', 'exclusion', 'or', 'limitation', 'of']
# ['damages']
# ['the']
# ['to']
# ['indemnity', 'you']
# ['indemnify', 'and', 'hold', 'the']
# ['project']
# ['and']
# ['harmless', 'from', 'all', 'liability']
# ['and']
# ['including', 'legal', 'fees', 'that', 'arise', 'directly', 'or', 'indirectly', 'from', 'any', 'of', 'the', 'following']
# ['you', 'do', 'or', 'cause']
# ['distribution', 'of', 'this']
# ['or', 'any']
# ['project', 'gutenberg', 'tm']
# ['or']
# ['or']
# ['to']
# ['project', 'gutenberg']
# ['and']
# ['by', 'the']
# ['of', 'the']
# ['of']
# ['of']
# ['to']
# ['the', 'project']
# ['to']
# ['to']
# ['project', 'gutenberg', 'literary', 'archive', 'foundation', 'the']
# ['project']
# ['is', 'a']
# ['c']
# ['under']
# ['the', 'laws', 'of']
# ['the', 'state']
# ['of']
# ['and']
# ['by', 'the']
# ['the']
# ['s']
# ['or']
# ['is']
# ['its']
# ['is']
# ['to', 'the']
# ['to', 'the']
# ['full']
# ['by']
# ['s']
# ['laws']
# ['and', 'your']
# ['state']
# ['s']
# ['the']
# ['s']
# ['office']
# ['is']
# ['at']
# ['s']
# ['but', 'its']
# ['and']
# ['are']
# ['its']
# ['business']
# ['office']
# ['is']
# ['at']
# ['business']
# ['and']
# ['up', 'to']
# ['be']
# ['at']
# ['the']
# ['s']
# ['and']
# ['at']
# ['for']
# ['and']
# ['about']
# ['to', 'the']
# ['and']
# ['without']
# ['to']
# ['the']
# ['that', 'can', 'be']
# ['in']
# ['by', 'the']
# ['of']
# ['to']
# ['to']
# ['with', 'the']
# ['the']
# ['with', 'the']
# ['of', 'the']
# ['are']
# ['not']
# ['and', 'it']
# ['and']
# ['to']
# ['and']
# ['do', 'not']
# ['in']
# ['we', 'have']
# ['not']
# ['of']
# ['to']
# ['the']
# ['of']
# ['for']
# ['we', 'cannot']
# ['and']
# ['do']
# ['from']
# ['we']
# ['the']
# ['of']
# ['of', 'the', 'project', 'gutenberg']
# ['of']
